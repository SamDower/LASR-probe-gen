# %% [markdown]
# # Standalone Probe Experiment

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Load input data

# %% [markdown]
# ### Generate output data

# %% [markdown]
# ### Generate input-output labels

# %% [markdown]
# ### Get input-output activations

# %% [markdown]
# ## Probe

# %% [markdown]
# ### Define probe architecture

# %% [markdown]
# ### Train probe

# %% [markdown]
# ### Evaluate probe
